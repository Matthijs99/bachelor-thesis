# %%
# %matplotlib notebook
import math
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
for file_name in ["06445.txt", "06440.txt", "06450.txt"]:
    f  = open(file_name, "r") 
    values = []
    for line in f:
        values.append(int(line))
    n = []
    Fn = []
    for i in range(130, 470):
        n.append(i/100)
        Fn_value = len([value for value in values if value > 10**(i/100)])/len(values)
        Fn.append(math.log10(Fn_value))
    plt.plot(n, Fn, label="p= " + str(int(file_name[:-4])/10000))
    
plt.xlabel("log n")
plt.ylabel("log F(n)")
plt.title("Simulatie voor standaard georiënteerde percolatie")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 06445
# 06440
# 06450

# %%
def poly(x, a, b):
    return a*x+b

# %%
# %matplotlib notebook
import math
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
#for file_name in ["0735.txt", "074.txt", "0745.txt", "0741.txt", "0742.txt", "0739.txt", "07405.txt", "07395.txt"]:
color_scheme = ["red", "green", "blue", "orange"]
c = 0
for file_name in ["07395.txt", "07400.txt", "07405.txt", "0741.txt"]:
    f  = open(file_name, "r") 
    values = []
    for line in f:
        values.append(int(line))
    n = []
    Fn = []
    for i in range(1300, 4699):
        n.append(i/1000)
        Fn_value = len([value for value in values if value > 10**(i/1000)])/len(values)
        Fn.append(math.log10(Fn_value))
    plt.plot(n, Fn, c=color_scheme[c], label="p= " + str(int(file_name[:-4])/10000))
    ab = np.polyfit(n, Fn, 1, full=True)[0]
    a = ab[0]
    b = ab[1]
    plt.plot(np.arange(1.3,4.68, 0.01), [poly(x, a, b) for x in np.arange(1.3,4.68, 0.01)], '--', c=color_scheme[c])
    c+=1
plt.xlabel("log n")
plt.ylabel("log F(n)")
plt.title("Simulatie voor ons georiënteerde rooster met eerstegraads polynoom fit")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for file_name in ["0735.txt", "074.txt", "0745.txt", "0741.txt", "0742.txt", "0739.txt", "07405.txt", "07395.txt"]:
    f  = open(file_name, "r") 
    values = []
    for line in f:
        values.append(int(line))
    n = []
    Fn = []
    for i in range(1300, 4699):
        n.append(i/1000)
        Fn_value = len([value for value in values if value > 10**(i/1000)])/len(values)
        Fn.append(math.log10(Fn_value))
    print(file_name, np.polyfit(n, Fn, 1, full=True))
# Out:
# 0735.txt (array([-0.13294577,  0.13364523]), array([5.97573549]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 074.txt (array([-0.05782607, -0.013986  ]), array([0.00253441]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 0745.txt (array([-0.02775558, -0.06028591]), array([0.14644668]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 0741.txt (array([-0.04612491, -0.03584677]), array([0.01776104]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 0742.txt (array([-0.04070791, -0.04480243]), array([0.0663687]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 0739.txt (array([-0.06766963,  0.0054282 ]), array([0.08170814]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# 07405.txt (array([-0.05206642, -0.02457079]), array([0.00244584]), 2, array([1.39657572, 0.22265725]), 7.547296121401814e-13)
# ...
